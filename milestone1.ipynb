# %% [markdown]
# MileStone 1:
#
# Download a dataset for any public repository
# Load the dataset into Jupyter Notebook
# Understand the dimensions of your data
# Identify the data types available in the dataset
# Get an idea of the missing values, duplicate entries and outliers in the data
# Look into descriptive statistics of your data
# Get an overview of the distribution of those variables, which are quantitative continuos
# Start Looking for better ways to show qualitative data in your dataset
# Play around with the correlation available between the features

# %%
import numpy 
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Download a dataset for any public repository
# ## Understand the dimensions of your data

# %%
mx_data = pd.read_csv("mexico_data.csv",low_memory=False)
mx_data
# Out:
#     Year  Agricultural land (Area)  Arable land (Area)  \
# 0   2020                       NaN                 NaN
# 1   2019                       NaN                 NaN
# 2   2018                 54.986497           12.297127
# 3   2017                 55.024049           12.297127
# 4   2016                 54.009620           11.403071
# ..   ...                       ...                 ...
# 56  1964                 50.438026            9.866509
# 57  1963                 50.468891            9.907662
# 58  1962                 50.504900            9.948816
# 59  1961                 50.575375           10.034723
# 60  1960                       NaN                 NaN
#
#     Renewable energy consumption (consumption)  \
# 0                                          NaN
# 1                                        10.34
# 2                                        10.03
# 3                                         9.99
# 4                                         9.22
# ..                                         ...
# 56                                         NaN
# 57                                         NaN
# 58                                         NaN
# 59                                         NaN
# 60                                         NaN
#
#     CO2 emissions from gaseous fuel consumption (kt)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                         151579.112
# ..                                               ...
# 56                                         13465.224
# 57                                         11668.394
# 58                                         11859.078
# 59                                          8041.731
# 60                                          6384.247
#
#     Access to electricity ( Population)  CO2 emissions (kt)  \
# 0                             99.400002                 NaN
# 1                             99.599998       449269.989014
# 2                             99.500000       452570.007324
# 3                            100.000000       471579.986572
# 4                             99.500000       473309.997559
# ..                                  ...                 ...
# 56                                  NaN                 NaN
# 57                                  NaN                 NaN
# 58                                  NaN                 NaN
# 59                                  NaN                 NaN
# 60                                  NaN                 NaN
#
#     Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                        57197.253906
# ..                                                ...
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
#
#     Total greenhouse gas emissions (kt of CO2 equivalent)
# 0                                                 NaN
# 1                                       653869.995117
# 2                                       654250.000000
# 3                                       671599.975586
# 4                                       674000.000000
# ..                                                ...
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
#
# [61 rows x 9 columns]

# %% [markdown]
# ## Identify the data types available in the dataset

# %%
mx_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 9 columns):
#  #   Column                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                     --------------  -----
#  0   Year                                                                                       61 non-null     int64
#  1   Agricultural land (Area)                                                                   58 non-null     float64
#  2   Arable land (Area)                                                                         58 non-null     float64
#  3   Renewable energy consumption (consumption)                                                 30 non-null     float64
#  4   CO2 emissions from gaseous fuel consumption (kt)                                           57 non-null     float64
#  5   Access to electricity ( Population)                                                        29 non-null     float64
#  6   CO2 emissions (kt)                                                                         30 non-null     float64
#  7   Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)  47 non-null     float64
#  8   Total greenhouse gas emissions (kt of CO2 equivalent)                                      30 non-null     float64
# dtypes: float64(8), int64(1)
# memory usage: 4.4 KB

# %% [markdown]
# ## Get an idea of the missing values, duplicate entries and outliers in the data

# %%
mx_data.isna().sum()
# Out:
# Year                                                                                          0
# Agricultural land (Area)                                                                      3
# Arable land (Area)                                                                            3
# Renewable energy consumption (consumption)                                                   31
# CO2 emissions from gaseous fuel consumption (kt)                                              4
# Access to electricity ( Population)                                                          32
# CO2 emissions (kt)                                                                           31
# Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)    14
# Total greenhouse gas emissions (kt of CO2 equivalent)                                        31
# dtype: int64

# %%
print(f"Number of rows: {mx_data.shape[0]}")
print(f"Number of columns: {mx_data.shape[1]}")
# Out:
# Number of rows: 61
# Number of columns: 9

# %% [markdown]
# ## Start Looking for better ways to show qualitative data in your dataset

# %%
mx_data.plot(x="Year",y=["Agricultural land (Area)","Arable land (Area)","Renewable energy consumption (consumption)","Access to electricity ( Population)"])
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
mx_data.plot(x="Year",y=["CO2 emissions from gaseous fuel consumption (kt)","CO2 emissions (kt)","Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)","Total greenhouse gas emissions (kt of CO2 equivalent)"])
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
sns.boxplot(x=mx_data["Agricultural land (Area)"])
# Out:
# <AxesSubplot:xlabel='Agricultural land (Area)'>

# %%
corr = mx_data.corr()
display(corr)
# Out:
#                                                         Year  \
# Year                                                1.000000
# Agricultural land (Area)                            0.791898
# Arable land (Area)                                  0.724016
# Renewable energy consumption (consumption)         -0.878463
# CO2 emissions from gaseous fuel consumption (kt)    0.960393
# Access to electricity ( Population)                 0.903289
# CO2 emissions (kt)                                  0.938657
# Other greenhouse gas emissions, HFC, PFC and SF...  0.241905
# Total greenhouse gas emissions (kt of CO2 equiv...  0.966569
#
#                                                     Agricultural land (Area)  \
# Year                                                                0.791898
# Agricultural land (Area)                                            1.000000
# Arable land (Area)                                                  0.939875
# Renewable energy consumption (consumption)                          0.508595
# CO2 emissions from gaseous fuel consumption (kt)                    0.642299
# Access to electricity ( Population)                                -0.413838
# CO2 emissions (kt)                                                 -0.512563
# Other greenhouse gas emissions, HFC, PFC and SF...                 -0.196537
# Total greenhouse gas emissions (kt of CO2 equiv...                 -0.511131
#
#                                                     Arable land (Area)  \
# Year                                                          0.724016
# Agricultural land (Area)                                      0.939875
# Arable land (Area)                                            1.000000
# Renewable energy consumption (consumption)                    0.247246
# CO2 emissions from gaseous fuel consumption (kt)              0.597842
# Access to electricity ( Population)                          -0.206024
# CO2 emissions (kt)                                           -0.255969
# Other greenhouse gas emissions, HFC, PFC and SF...           -0.170918
# Total greenhouse gas emissions (kt of CO2 equiv...           -0.261023
#
#                                                     Renewable energy consumption (consumption)  \
# Year                                                                                 -0.878463
# Agricultural land (Area)                                                              0.508595
# Arable land (Area)                                                                    0.247246
# Renewable energy consumption (consumption)                                            1.000000
# CO2 emissions from gaseous fuel consumption (kt)                                     -0.951351
# Access to electricity ( Population)                                                  -0.855574
# CO2 emissions (kt)                                                                   -0.968839
# Other greenhouse gas emissions, HFC, PFC and SF...                                   -0.875721
# Total greenhouse gas emissions (kt of CO2 equiv...                                   -0.955447
#
#                                                     CO2 emissions from gaseous fuel consumption (kt)  \
# Year                                                                                        0.960393
# Agricultural land (Area)                                                                    0.642299
# Arable land (Area)                                                                          0.597842
# Renewable energy consumption (consumption)                                                 -0.951351
# CO2 emissions from gaseous fuel consumption (kt)                                            1.000000
# Access to electricity ( Population)                                                         0.895009
# CO2 emissions (kt)                                                                          0.969024
# Other greenhouse gas emissions, HFC, PFC and SF...                                          0.413312
# Total greenhouse gas emissions (kt of CO2 equiv...                                          0.979758
#
#                                                     Access to electricity ( Population)  \
# Year                                                                           0.903289
# Agricultural land (Area)                                                      -0.413838
# Arable land (Area)                                                            -0.206024
# Renewable energy consumption (consumption)                                    -0.855574
# CO2 emissions from gaseous fuel consumption (kt)                               0.895009
# Access to electricity ( Population)                                            1.000000
# CO2 emissions (kt)                                                             0.927820
# Other greenhouse gas emissions, HFC, PFC and SF...                             0.854042
# Total greenhouse gas emissions (kt of CO2 equiv...                             0.933425
#
#                                                     CO2 emissions (kt)  \
# Year                                                          0.938657
# Agricultural land (Area)                                     -0.512563
# Arable land (Area)                                           -0.255969
# Renewable energy consumption (consumption)                   -0.968839
# CO2 emissions from gaseous fuel consumption (kt)              0.969024
# Access to electricity ( Population)                           0.927820
# CO2 emissions (kt)                                            1.000000
# Other greenhouse gas emissions, HFC, PFC and SF...            0.897719
# Total greenhouse gas emissions (kt of CO2 equiv...            0.995079
#
#                                                     Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)  \
# Year                                                                                         0.241905
# Agricultural land (Area)                                                                    -0.196537
# Arable land (Area)                                                                          -0.170918
# Renewable energy consumption (consumption)                                                  -0.875721
# CO2 emissions from gaseous fuel consumption (kt)                                             0.413312
# Access to electricity ( Population)                                                          0.854042
# CO2 emissions (kt)                                                                           0.897719
# Other greenhouse gas emissions, HFC, PFC and SF...                                           1.000000
# Total greenhouse gas emissions (kt of CO2 equiv...                                           0.897701
#
#                                                     Total greenhouse gas emissions (kt of CO2 equivalent)
# Year                                                                                         0.966569
# Agricultural land (Area)                                                                    -0.511131
# Arable land (Area)                                                                          -0.261023
# Renewable energy consumption (consumption)                                                  -0.955447
# CO2 emissions from gaseous fuel consumption (kt)                                             0.979758
# Access to electricity ( Population)                                                          0.933425
# CO2 emissions (kt)                                                                           0.995079
# Other greenhouse gas emissions, HFC, PFC and SF...                                           0.897701
# Total greenhouse gas emissions (kt of CO2 equiv...                                           1.000000

# %%
sns.heatmap(
    corr,
    annot=True,
)
# Out:
# <AxesSubplot:>
